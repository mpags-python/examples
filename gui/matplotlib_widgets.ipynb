# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib.widgets import Button, Slider

fig = plt.figure()
plot_ax = fig.add_axes([0.1, 0.3, 0.8, 0.6])
N0 = 50
x = np.random.uniform(size=N0)
y = np.random.normal(size=N0)
xyplot, = plot_ax.plot(x, y, 'o')
plot_ax.axis([0, 1, -3, 3])

slider_ax = fig.add_axes([0.50, 0.1, 0.3, 0.025])
nslider = Slider(slider_ax, 'N', 0, 100, valinit=N0, valfmt='%0.0f')

button_ax = fig.add_axes([0.20, 0.05, 0.2, 0.125])
button = Button(button_ax, 'Update')

def callback(event):
    N = int(round(nslider.val))
    xyplot.set_xdata(np.random.uniform(size=N))
    xyplot.set_ydata(np.random.normal(size=N))
    plt.draw()

button.on_clicked(callback)
nslider.on_changed(callback);
# Out:
# <img src="data:image/png;base64,..." width="640">
