# %%
import numpy as np

# %%
x = np.array([ 1,  3,  9, 14, 15, 19, 20, 21, 30, 35,
              40, 41, 42, 47, 54, 56, 67, 69, 72, 88])

y = np.array([33, 68, 34, 34, 37, 65, 37, 44, 48, 49,
              53, 49, 50, 48, 56, 60, 61, 63, 44, 71])

e = np.array([3.6, 3.9, 2.6, 3.4, 3.8, 14.8, 2.2, 2.1, 2.3, 3.8,
              2.2, 2.8, 3.9, 3.1, 3.4, 2.6, 3.4, 3.7, 2.0, 3.5])

# %% [markdown]
# ### matplotlib notebook

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
fig = plt.figure()
plt.scatter(x, y, 1000/e**2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('resistance, $\Omega$ ohms')
plt.ylabel('size of universe, $S$ Gpc')
plt.tight_layout()

# %% [markdown]
# ### mpld3

# %%
import mpld3
mpld3.display(fig)
# Out:
# /Users/spb/anaconda/envs/course/lib/python3.8/site-packages/mpld3/mplexporter/exporter.py:267: MatplotlibDeprecationWarning:
# The get_offset_position function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   offset_order = offset_dict[collection.get_offset_position()]
# <style>
#
# </style>
#
# <div id="fig_el637791403315668259203777923552"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el637791403315668259203777923552", {"width": 640.0, "height": 480.0, "axes": [{"bbox": [0.10316840277777779, 0.12766203703703705, 0.8733940972222222, 0.841087962962963], "xlim": [-3.3500000000000005, 92.35], "ylim": [31.1, 72.9], "xdomain": [-3.3500000000000005, 92.35], "ydomain": [31.1, 72.9], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 10, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el63779140331566825824", "lines": [], "paths": [], "markers": [], "texts": [{"text": "resistance, $\\Omega$ ohms", "position": [0.5, -0.0725196091922389], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el63779140331582587760"}, {"text": "size of universe, $S$ Gpc", "position": [-0.05908661730358297, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el63779140331582589680"}], "collections": [{"offsets": "data01", "xindex": 0, "yindex": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathtransforms": [[12.200145293859487, 0.0, 0.0, 12.200145293859487, 0.0, 0.0], [11.26167257894722, 0.0, 0.0, 11.26167257894722, 0.0, 0.0], [16.89250886842083, 0.0, 0.0, 16.89250886842083, 0.0, 0.0], [12.917800899380635, 0.0, 0.0, 12.917800899380635, 0.0, 0.0], [11.558032383656359, 0.0, 0.0, 11.558032383656359, 0.0, 0.0], [2.967602909317173, 0.0, 0.0, 2.967602909317173, 0.0, 0.0], [19.963874117224616, 0.0, 0.0, 19.963874117224616, 0.0, 0.0], [20.914534789473407, 0.0, 0.0, 20.914534789473407, 0.0, 0.0], [19.095879590388765, 0.0, 0.0, 19.095879590388765, 0.0, 0.0], [11.558032383656359, 0.0, 0.0, 11.558032383656359, 0.0, 0.0], [19.963874117224616, 0.0, 0.0, 19.963874117224616, 0.0, 0.0], [15.685901092105057, 0.0, 0.0, 15.685901092105057, 0.0, 0.0], [11.26167257894722, 0.0, 0.0, 11.26167257894722, 0.0, 0.0], [14.167910663836825, 0.0, 0.0, 14.167910663836825, 0.0, 0.0], [12.917800899380635, 0.0, 0.0, 12.917800899380635, 0.0, 0.0], [16.89250886842083, 0.0, 0.0, 16.89250886842083, 0.0, 0.0], [12.917800899380635, 0.0, 0.0, 12.917800899380635, 0.0, 0.0], [11.870411637268692, 0.0, 0.0, 11.870411637268692, 0.0, 0.0], [21.960261528947076, 0.0, 0.0, 21.960261528947076, 0.0, 0.0], [12.548720873684045, 0.0, 0.0, 12.548720873684045, 0.0, 0.0]], "alphas": [null], "edgecolors": ["#1F77B4"], "facecolors": ["#1F77B4"], "edgewidths": [1.0], "offsetcoordinates": "data", "pathcoordinates": "display", "zorder": 1, "id": "el63779140331582783344"}], "images": [], "sharex": [], "sharey": []}], "data": {"data01": [[1.0, 33.0], [3.0, 68.0], [9.0, 34.0], [14.0, 34.0], [15.0, 37.0], [19.0, 65.0], [20.0, 37.0], [21.0, 44.0], [30.0, 48.0], [35.0, 49.0], [40.0, 53.0], [41.0, 49.0], [42.0, 50.0], [47.0,  ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.1.js", function(){
#
#          mpld3.draw_figure("fig_el637791403315668259203777923552", {"width": 640.0, "height": 480.0, "axes": [{"bbox": [0.10316840277777779, 0.12766203703703705, 0.8733940972222222, 0.841087962962963], "xlim": [-3.3500000000000005, 92.35], "ylim": [31.1, 72.9], "xdomain": [-3.3500000000000005, 92.35], "ydomain": [31.1, 72.9], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 10, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el63779140331566825824", "lines": [], "paths": [], "markers": [], "texts": [{"text": "resistance, $\\Omega$ ohms", "position": [0.5, -0.0725196091922389], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el63779140331582587760"}, {"text": "size of universe, $S$ Gpc", "position": [-0.05908661730358297, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el63779140331582589680"}], "collections": [{"offsets": "data01", "xindex": 0, "yindex": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathtransforms": [[12.200145293859487, 0.0, 0.0, 12.200145293859487, 0.0, 0.0], [11.26167257894722, 0.0, 0.0, 11.26167257894722, 0.0, 0.0], [16.89250886842083, 0.0, 0.0, 16.89250886842083, 0.0, 0.0], [12.917800899380635, 0.0, 0.0, 12.917800899380635, 0.0, 0.0], [11.558032383656359, 0.0, 0.0, 11.558032383656359, 0.0, 0.0], [2.967602909317173, 0.0, 0.0, 2.967602909317173, 0.0, 0.0], [19.963874117224616, 0.0, 0.0, 19.963874117224616, 0.0, 0.0], [20.914534789473407, 0.0, 0.0, 20.914534789473407, 0.0, 0.0], [19.095879590388765, 0.0, 0.0, 19.095879590388765, 0.0, 0.0], [11.55803238365635

# %%
mpld3.save_html(fig, open('scatter_mpld3.html', 'w'))

# %% [markdown]
# ### bokeh

# %%
import bokeh.plotting as bk
bk.output_notebook()
p = bk.figure()
p.scatter(x,y, radius=5/e, line_color=None)
bk.show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ec5229db-2dec-4109-9443-81471d2613c9" data-root-id="1002"></div>

# %%
bk.save(p, 'scatter_bokeh.html')
# Out:
# /Users/spb/anaconda/envs/course/lib/python3.8/site-packages/bokeh/io/saving.py:126: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# /Users/spb/anaconda/envs/course/lib/python3.8/site-packages/bokeh/io/saving.py:139: UserWarning: save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'
#   warn("save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'")
# '/Users/spb/Dropbox/Work/teaching/mpags_python/notebooks/examples/plotting/scatter_bokeh.html'
